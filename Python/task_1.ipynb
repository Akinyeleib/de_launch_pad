# %%
import requests

# %%
try:
    global req
    req = requests.get('https://zenquotes.io/?api=quotes')
except:
    print('Error occured')

# %%
response = req.json()
response
# Out:
# [{'q': 'Anger is an acid that can do more harm to the vessel in which it is stored than to anything on which it is poured.',
#   'a': 'Mark Twain',
#   'c': '114',
#   'h': '<blockquote>&ldquo;Anger is an acid that can do more harm to the vessel in which it is stored than to anything on which it is poured.&rdquo; &mdash; <footer>Mark Twain</footer></blockquote>'},
#  {'q': 'Truth is such a rare thing, it is delighted to tell it.',
#   'a': 'Emily Dickinson',
#   'c': '55',
#   'h': '<blockquote>&ldquo;Truth is such a rare thing, it is delighted to tell it.&rdquo; &mdash; <footer>Emily Dickinson</footer></blockquote>'},
#  {'q': 'Wherever there is danger, there lurks opportunity; wherever there is opportunity, there lurks danger. The two are inseparable.',
#   'a': 'Earl Nightingale',
#   'c': '126',
# ...

# %%
restructured = []

for quote in response:
    formatted = {}
    for key in quote:
        key_name = 'quote' if key == 'q' else 'author' if key == 'a' else 'length' if key == 'c' else key
        formatted[key_name] = quote[key]
    restructured.append(formatted)
len(restructured)
# Out:
# 50

# %%
restructured
# Out:
# [{'quote': 'All men who have achieved great things have been great dreamers. ',
#   'author': 'Orison Swett Marden',
#   'length': '65',
#   'h': '<blockquote>&ldquo;All men who have achieved great things have been great dreamers. &rdquo; &mdash; <footer>Orison Swett Marden</footer></blockquote>'},
#  {'quote': 'Passion creates, addiction consumes.',
#   'author': 'Gabor Mate',
#   'length': '36',
#   'h': '<blockquote>&ldquo;Passion creates, addiction consumes.&rdquo; &mdash; <footer>Gabor Mate</footer></blockquote>'},
#  {'quote': 'The chief cause of failure and unhappiness is trading what you want most for what you want right now.',
#   'author': 'Zig Ziglar',
#   'length': '101',
#   'h': '<blockquote>&ldquo;The chief cause of failure and unhappiness is trading what you want most for what you want right now.&rdquo; &mdash; <footer>Zig Ziglar</footer></blockquote>'},
# ...

# %%
'''
CREATE TABLE users (
    id SERIAL PRIMARY KEY,
    email VARCHAR(255) UNIQUE NOT NULL,
    name VARCHAR(100) NOT NULL,
    subscription_status VARCHAR(10) CHECK (subscription_status IN ('active', 'inactive')) NOT NULL DEFAULT 'inactive',
    email_frequency VARCHAR(10) CHECK (email_frequency IN ('daily', 'weekly')) NOT NULL DEFAULT 'weekly',
    created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
);

'''
# Out:
# "\nCREATE TABLE users (\n    id SERIAL PRIMARY KEY,\n    email VARCHAR(255) UNIQUE NOT NULL,\n    name VARCHAR(100) NOT NULL,\n    subscription_status VARCHAR(10) CHECK (subscription_status IN ('active', 'inactive')) NOT NULL DEFAULT 'inactive',\n    email_frequency VARCHAR(10) CHECK (email_frequency IN ('daily', 'weekly')) NOT NULL DEFAULT 'weekly',\n    created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP\n);\n\n"

# %%
### 3. Email Module

# %%
from send_email import send_email as email

# %%
email
# Out:
# <function send_email.send_email(to_email, subject, body)>

# %%
# Retrieve daily users
query = "SELECT email, name FROM users WHERE subscription_status = 'active' AND email_frequency = 'weekly';"

# %%
# Use Pandas to retrieve data

# %%
import pandas as pd
import psycopg2
from sqlalchemy import create_engine

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
DB_USERNAME = os.getenv('DB_USERNAME')
DB_PASSWORD = os.getenv('DB_PASSWORD')
DB_HOST = os.getenv('DB_HOST')
DB_PORT = os.getenv('DB_PORT')
# DB_NAME = os.getenv('DB_NAME')
DB_NAME = 'postgres'

# %%
# docker run --hostname=1a1c03941cf2 --env=POSTGRES_USER=root --env=POSTGRES_PASSWORD=root postgres

# %%
engine_template = f"postgresql://{DB_USERNAME}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/postgres"
engine_template
# Out:
# 'postgresql://root:root@localhost:5432/postgres'

# %%
engine = create_engine(engine_template)

# %%
df = pd.read_sql(query, engine)

# %%
df.head(3)
# Out:
#                   email     name
# 0  iakinyele3@gmail.com  Ibrahim
# 1  akolawale4@gmail.com  Ibrahim

# %%
import smtplib, os
from dotenv import load_dotenv
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart

load_dotenv()

from_email = os.getenv('EMAIL_ADDRESS')
password = os.getenv('EMAIL_PASSWORD')
smtp_server = os.getenv('SMTP_SERVER', 'smtp.gmail.com')
smtp_port = int(os.getenv('SMTP_PORT', 587))

def email(to_email, subject, body):

    # Create the email

    try:

        msg = MIMEMultipart()
        msg['From'] = from_email
        msg['To'] = to_email
        msg['Subject'] = subject

        msg.attach(MIMEText(body, 'plain'))

        # Connect to the server
        with smtplib.SMTP_SSL(smtp_server, smtp_port) as server:
            server.login(from_email, password)
            server.sendmail(from_email, to_email, msg.as_string())

        print(f"Email sent to {to_email}")

    except Exception as e:
        print(f"Failed to send email: {e}")

# %%
for index, row in df.iterrows():
    recipient_email = row['email']
    recipient_name = row['name']
    
    quote_of_the_day = restructured[index % len(restructured)]
    quote_text = quote_of_the_day['quote']
    quote_author = quote_of_the_day['author']
    
    subject = "Your Weekly Quote"
    body = f"Hello {recipient_name},\n\nHere is your weekly quote:\n\n\"{quote_text}\"\n- {quote_author}\n\nHave a great week!"
    
    email(recipient_email, subject, body)
# Out:
# Email sent to iakinyele3@gmail.com
# Email sent to akolawale4@gmail.com
